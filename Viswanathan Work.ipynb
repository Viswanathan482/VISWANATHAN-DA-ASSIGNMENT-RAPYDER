# %%
##Libraries
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("Data.csv")
data
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1      3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2      ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3      7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4      2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
# ...                                 ...                        ...
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                                Job Title  \
# 0                                  Digital Media Planner
# ...

# %%
data.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  9be62c49a0b7ebe982a4af1edaa7bc5f  2019-07-05 01:46:07 +0000
# 1  3c52d436e39f596b22519da2612f6a56  2019-07-06 08:04:50 +0000
# 2  ffad8a2396c60be2bf6d0e2ff47c58d4  2019-08-05 15:50:44 +0000
# 3  7b921f51b5c2fb862b4a5f7a54c37f75  2019-08-05 15:31:56 +0000
# 4  2d8b7d44e138a54d5dc841163138de50  2019-07-05 02:48:29 +0000
#
#                                            Job Title  \
# 0                              Digital Media Planner
# 1                           Online Bidding Executive
# 2   Trainee Research/ Research Executive- Hi- Tec...
# 3                                  Technical Support
# 4                  Software Test Engineer -hyderabad
#
#                      Job Salary Job Experience Required  \
# 0   Not Disclosed by Recruiter               5 - 10 yrs
# 1   Not Disclosed by Recruiter                2 - 5 yrs
# 2   Not Disclosed by Recruiter                0 - 1 yrs
# ...

# %%
data.tail()
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 29995  3510f2146b514f112eaa9706a16b3900  2019-07-06 21:12:51 +0000
# 29996  4af8c56f5b4c535b1974065003f2d548  2019-08-05 23:55:08 +0000
# 29997  43d5b806b26ed99d3ebfc8f366b4cdd1  2019-08-05 09:41:29 +0000
# 29998  8bc87d14cf56564f16b6d4bae80180be  2019-08-06 01:44:55 +0000
# 29999  9c7045d111814a6f39fe461eab2b0bf8  2019-07-06 22:24:55 +0000
#
#                                          Job Title  \
# 29995                        MTS-Software-Engineer
# 29996                  Client Relationship Manager
# 29997                             Assoc. Prof.- CS
# 29998   Application/Cyber Security Specialist-Pune
# 29999                   Press Release Writer - SEO
#
#                          Job Salary Job Experience Required  \
# 29995   Not Disclosed by Recruiter               9 - 12 yrs
# 29996   Not Disclosed by Recruiter                1 - 5 yrs
# 29997   Not Disclosed by Recruiter                4 - 6 yrs
# ...

# %%
data.isnull().sum()
# Out:
# Uniq Id                       0
# Crawl Timestamp               0
# Job Title                   575
# Job Salary                   50
# Job Experience Required     573
# Key Skills                 1271
# Role Category              2305
# Location                    577
# Functional Area             573
# Industry                    573
# Role                        901
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Uniq Id                  30000 non-null  object
#  1   Crawl Timestamp          30000 non-null  object
#  2   Job Title                29425 non-null  object
#  3   Job Salary               29950 non-null  object
#  4   Job Experience Required  29427 non-null  object
#  5   Key Skills               28729 non-null  object
#  6   Role Category            27695 non-null  object
#  7   Location                 29423 non-null  object
#  8   Functional Area          29427 non-null  object
#  9   Industry                 29427 non-null  object
#  10  Role                     29099 non-null  object
# dtypes: object(11)
# memory usage: 2.5+ MB

# %% [markdown]
# # Top 20 cities with job opportunities

# %%
cities =data.Location.str.strip().str.split(",", expand = True)[0].str.split(" ", expand = True)[0].value_counts().reset_index()
cities.columns = ["Location", "Job_Opportunities"]
top_20_cities = cities[:20]

# %%
top_20_cities
# Out:
#       Location  Job_Opportunities
# 0    Bengaluru               6228
# 1       Mumbai               4577
# 2        Delhi               3305
# 3         Pune               2821
# 4    Hyderabad               2697
# 5      Gurgaon               2199
# 6      Chennai               1959
# 7      Kolkata               1491
# 8        Noida               1428
# 9    Ahmedabad               1281
# 10  Chandigarh                400
# 11        Navi                225
# 12   Faridabad                150
# 13   Ghaziabad                114
# 14     Greater                 89
# 15       Thane                 71
# 16      Jaipur                 24
# 17      Mohali                 17
# 18       Anand                 12
# 19      Nagpur                 12

# %%
##Visualization
plt.figure(figsize = (12, 10))
plt.bar(top_20_cities.Location, top_20_cities.Job_Opportunities, color = "Purple")
plt.xlabel("Locations")
plt.ylabel("Job Opportunities")
plt.xticks(top_20_cities.Location, rotation = "70")
plt.title("Job Opportunities in Top 20 Locations", fontdict={"fontsize" :20})
plt.show()

# %% [markdown]
# # Top 20 Industries with Job Opportunities

# %%
import re
Industries = pd.DataFrame(data.Industry.str.split(",", expand = True).values.ravel("f"),columns = ["Industry"])
Industries = Industries.dropna()
Industries.Industry = Industries.Industry.apply(lambda x: re.sub("[^A-Za-z0-9 -]+", ",", x))
Industries = pd.DataFrame(Industries.Industry.str.split(",", expand = True).values.ravel("f"), columns = ["Industry"])
Industries = Industries.dropna()
Industries.Industry = Industries.Industry.str.lstrip().str.rstrip()

#top 20 industries
Industries = Industries.Industry.value_counts().reset_index()
Industries.columns =["Industry", "Job_Opportunities"]
top_20_Industries = Industries[:20]

# %%
top_20_Industries
# Out:
#               Industry  Job_Opportunities
# 0          IT-Software              10798
# 1    Software Services              10798
# 2          Recruitment               2745
# 3             Staffing               2745
# 4          Call Centre               1909
# 5                  BPO               1909
# 6   Financial Services               1778
# 7              Banking               1778
# 8              Broking               1778
# 9                 ITeS               1754
# 10           Education               1389
# 11            Training               1389
# 12            Teaching               1389
# 13            Internet               1084
# 14           Hospitals                702
# 15          Healthcare                702
# 16             Medical                702
# 17           Ecommerce                616
# 18         Engineering                580
# 19              Metals                580

# %%
##Visualization
plt.figure(figsize = (12, 10))
plt.bar(top_20_Industries.Industry, top_20_Industries.Job_Opportunities, color = "Orange")
plt.xlabel("Industries")
plt.ylabel("Job Opportunities")
plt.xticks(top_20_Industries.Industry, rotation = "70")
plt.title("Job Opportunities in Top 20 Industries", fontdict={"fontsize" :20})
plt.show()

# %% [markdown]
# # Top 20 Job categories

# %%
JobCategory = data["Role Category"].str.lstrip().str.rstrip().value_counts().reset_index()
JobCategory.columns = ["Role_Category", "Job_Opportunities"]
top_20_JobCategory = JobCategory[:20]

# %%
top_20_JobCategory
# Out:
#                                  Role_Category  Job_Opportunities
# 0                         Programming & Design               8551
# 1                                        Voice               2385
# 2                                 Retail Sales               2359
# 3                         HR/ Recruitment / IR               1133
# 4   Admin/Maintenance/Security/Datawarehousing                928
# 5                                     Accounts                882
# 6                            Senior Management                880
# 7                                        Other                865
# 8                              Corporate Sales                704
# 9         Production/Manufacturing/Maintenance                592
# 10        System Design/Implementation/ERP/CRM                507
# 11                                   Marketing                487
# 12                        Medical Professional                438
# ...

# %%
##Visualozation
plt.figure(figsize = (12, 10))
plt.bar(top_20_JobCategory.Role_Category, top_20_JobCategory.Job_Opportunities, color = "blue")
plt.xlabel("Job Catergories")
plt.ylabel("Job Opportunities")
plt.xticks(top_20_JobCategory.Role_Category, rotation = "vertical")
plt.title("Top 20 Job Categories", fontdict={"fontsize" :20})
plt.show()

# %% [markdown]
# # Top 20 Job Roles

# %%
Job_Role = data.Role.str.lstrip().str.rstrip().value_counts().reset_index()
Job_Role.columns = ["Role", "Job_Opportunities"]
top_20_Job_Role = Job_Role[:20]

# %%
top_20_Job_Role
# Out:
#                                           Role  Job_Opportunities
# 0                           Software Developer               6396
# 1   Associate/Senior Associate -(NonTechnical)               1728
# 2           Sales/Business Development Manager               1561
# 3                      Sales Executive/Officer               1168
# 4                                        Other                896
# 5                     Team Lead/Technical Lead                847
# 6      Associate/Senior Associate -(Technical)                513
# 7                Accounts Executive/Accountant                511
# 8                        Recruitment Executive                427
# 9                             Testing Engineer                408
# 10                                     Fresher                380
# 11                         Technical Architect                366
# 12                        System Administrator                318
# ...

# %%
#Visualization
plt.figure(figsize = (12, 10))
plt.bar(top_20_Job_Role.Role, top_20_Job_Role.Job_Opportunities, color = "red")
plt.xlabel("Job Roles")
plt.ylabel("Job Opportunities")
plt.xticks(top_20_Job_Role.Role, rotation = "vertical")
plt.title("Top 20 Job Categories", fontdict={"fontsize" :20})
plt.show()

# %% [markdown]
# # Top 5 locations for Top 20 Industries

# %%
top5locations = pd.DataFrame({"Location": data.Location.str.split(",", expand = True)[0],"Industry": data.Industry.str.split(",", expand = True)[0]})
top5locations.dropna(inplace = True)

# %%
top5cities = pd.crosstab(top5locations.Location, top5locations.Industry).reset_index()
top5cities = top5cities.melt(id_vars = "Location", value_name = "Job_Opportunities")
top5cities = top5cities.sort_values(by = ["Industry", "Job_Opportunities"], ascending = False).reset_index(drop = True)
top5cities = top5cities.dropna()
top5cities = top5cities.sort_values(by = "Job_Opportunities", ascending = False).reset_index(drop = True)

top20industries = top5cities.groupby("Industry").sum().reset_index().sort_values(by = "Job_Opportunities", ascending = False)[:20]

# %%
import plotly.express as px

# %%
# saved industry name in list for fetching only 5 same name industry or only five Location of particular indusry

industry20 = top20industries.Industry.reset_index(drop = True)
limit = 0
something = pd.DataFrame(columns=["Location", "Industry", "Job_Opportunities"])
for j in range(20):
    limit = 0
    for i in range (top5cities.size):
        if limit == 5:
            break
        if industry20[j] == top5cities.loc[i, "Industry"]:
            something = something.append(top5cities.loc[i], ignore_index = True)
            limit += 1

# %%
# plot pie chart of top 5 location of top 20 Industry
for i in industry20:
    top20industries = something.loc[something.Industry == i, ["Location", "Job_Opportunities"]]
    fig = px.pie(top20industries, names = "Location", values = "Job_Opportunities", color = "Location",
                 title = "Top 5 Location for " + i + " Industry")
    fig.show()
# Out:
# <div>                            <div id="447295f0-b72b-4a75-94dc-85e9b589bfc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("447295f0-b72b-4a75-94dc-85e9b589bfc2")) {                    Plotly.newPlot(                        "447295f0-b72b-4a75-94dc-85e9b589bfc2",                        [{"customdata":[["Bengaluru"],["Mumbai"],["Hyderabad"],["Pune"],["Kolkata"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Location=%{customdata[0]}<br>Job_Opportunities=%{value}<extra></extra>","labels":["Bengaluru","Mumbai","Hyderabad","Pune","Kolkata"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A"]},"name":"","showlegend":true,"values":[2530,1119,1070,1027,904],"type":"pie"}],                        {"template"
# ...

# %% [markdown]
# # Skills Required for various Jobs

# %%
skills = data[["Role Category", "Key Skills"]].copy()
classy = skills['Key Skills'].str.split("|", expand = True) # split keys
classy = pd.concat([skills, classy], axis = 1) # concat splited keys columns
classy = classy.melt(id_vars = ["Role Category", "Key Skills"], var_name = "Job_Opportunities", value_name = "Skills")
# transform Key skills using melt
classy = classy.dropna() 
classy.Job_Opportunities = 1 # assign job opportunites value 1 for counting purpose
classy = classy.groupby(["Role Category", "Skills"]).Job_Opportunities.sum().reset_index()
# group by role and skills and find sum of job opportunities
classy = classy.sort_values(by = "Job_Opportunities", ascending = False).reset_index(drop = True)

# %%
skillsjobcat = pd.DataFrame(columns = ["Role Category", "Skills", "Job_Opportunities"])
rolecategory = top_20_JobCategory.Role_Category
limit = 0
for i in range(20):
    limit = 0
    for j in range(classy.size):
        if limit == 10:
            break
        if rolecategory[i] == classy.loc[j, "Role Category"]:
            skillsjobcat = skillsjobcat.append(classy.loc[j])
            limit += 1

# %%
px.sunburst(data_frame = skillsjobcat, values = "Job_Opportunities", path = ["Role Category", "Skills"],
            color = "Role Category", title = "Skills Required for various Job Categories",height = 600)
# Out:
# <div>                            <div id="fc990d27-131b-4abc-8ae7-2382dc1608c7" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc990d27-131b-4abc-8ae7-2382dc1608c7")) {                    Plotly.newPlot(                        "fc990d27-131b-4abc-8ae7-2382dc1608c7",                        [{"branchvalues":"total","customdata":[["Finance/Audit"],["Accounts"],["Finance/Audit"],["Senior Management"],["Creative"],["Back Office/Web/Transaction Processing"],["Creative"],["Accounts"],["HR/ Recruitment / IR"],["Creative"],["Engineering Design"],["Engineering Design"],["Production/Manufacturing/Maintenance"],["Engineering Design"],["University Level"],["Teachers"],["System Design/Implementation/ERP/CRM"],["Other"],["Marketing"],["Other"],["Back Office/Web/T
# ...

# %% [markdown]
# # Average salary offered in Top 10 cities

# %%
salary_loc = data[["Job Salary", "Location"]].copy()
salary_loc["New_Location"] = salary_loc.Location.str.strip().str.split(",", expand = True)[0]

classy = salary_loc['Job Salary'].apply(lambda x: re.sub("[^0-9 -]", "", str(x)))
salary_loc["Min_Salary"] = classy.str.strip().str.split("-", expand = True)[0]
salary_loc["Max_Salary"] = classy.str.strip().str.split("-", expand = True)[1]
salary_loc.dropna(inplace = True)

# remove space between digits
salary_loc.Min_Salary = salary_loc.Min_Salary.str.replace(" ", "")
salary_loc.Max_Salary = salary_loc.Max_Salary.str.replace(" ", "")

# put 0 where value is totally empty
salary_loc.loc[salary_loc.Max_Salary == "", "Max_Salary"] = "0"
salary_loc.loc[salary_loc.Min_Salary == "", "Min_Salary"] = "0"

# convert it into 
salary_loc.Min_Salary = salary_loc.Min_Salary.astype("int64")
salary_loc.Max_Salary = salary_loc.Max_Salary.astype("int64")
salary_loc.drop(columns = ["Location", "Job Salary"], inplace = True) # drop old columns

# %%
income = salary_loc.groupby("New_Location").median().reset_index() # find average of salary

toplocation_salary = pd.DataFrame()
loc_list = top_20_cities.Location
for i in range(20):
    for j in range(income.New_Location.size):
        if loc_list[i] == income.loc[j, "New_Location"]:
            toplocation_salary = toplocation_salary.append(income.loc[j])
            break

toplocation_salary = toplocation_salary.reset_index(drop = True)
toplocation_salary = toplocation_salary[:10].copy() # find top 10 
toplocation_salary.rename(columns = {"New_Location": "Location"}, inplace = True)
toplocation_salary.Max_Salary = toplocation_salary.Max_Salary.astype("int64")
toplocation_salary.Min_Salary = toplocation_salary.Min_Salary.astype("int64")
toplocation_salary = toplocation_salary[toplocation_salary.columns[[2, 1, 0]]] # change column order

# %%
plt.figure(figsize = (12, 10))
ax = plt.subplot(111)
ax.bar(toplocation_salary.index - 0.2, toplocation_salary.Min_Salary, color = "pink", width = 0.4, label = "Min Salary")
ax.bar(toplocation_salary.index +0.2, toplocation_salary.Max_Salary, color = "purple", width = 0.4, label = "Max Salary")
plt.xlabel("Location")
plt.ylabel("Average Salary")
plt.xticks([i for i in toplocation_salary.index] ,toplocation_salary.Location)
plt.legend()
plt.show()

# %% [markdown]
# # Average salary offered by the top 10 Industries in the top 5 locations

# %%
new_avg_sal_ind = data[["Location", "Industry", "Job Salary"]].copy() # preparing data
new_avg_sal_ind.Location = new_avg_sal_ind.Location.str.split(",", expand = True)[0] # preparing location
new_avg_sal_ind.Industry = new_avg_sal_ind.Industry.str.split(",", expand = True)[0] # preparing industry
new_avg_sal_ind['Job Salary'] = new_avg_sal_ind['Job Salary'].apply(lambda x: re.sub("[^0-9 -]", "", str(x))) # salary
new_avg_sal_ind["Min_Salary"] = new_avg_sal_ind['Job Salary'].str.split("-", expand = True)[0] # min salary
new_avg_sal_ind["Max_Salary"] = new_avg_sal_ind['Job Salary'].str.split("-", expand = True)[1] # max salary
new_avg_sal_ind.Min_Salary = new_avg_sal_ind.Min_Salary.str.replace(" ", "")
new_avg_sal_ind.Max_Salary = new_avg_sal_ind.Max_Salary.str.replace(" ", "")
new_avg_sal_ind.loc[new_avg_sal_ind.Min_Salary == "", "Min_Salary"] = "0"
new_avg_sal_ind.loc[new_avg_sal_ind.Max_Salary == "", "Max_Salary"] = "0"
new_avg_sal_ind.dropna(inplace = True)
new_avg_sal_ind.Min_Salary = new_avg_sal_ind.Min_Salary.astype("int64")
new_avg_sal_ind.Max_Salary = new_avg_sal_ind.Max_Salary.astype("int64")

# %%
classy = new_avg_sal_ind.groupby(["Industry", "Location"]).median().reset_index()
# group industry and location and find average of salary
classy.Industry = classy.Industry.str.upper() # convert upper case of industry
lst_Industry = Industries.Industry[:25] # get 25 top industry
lst_Location = top_20_cities.Location # get 20 top industry
limit = 0
top_10_avg_sal_industry_location = pd.DataFrame(columns = ["Industry", "Location", "Max_Salary", "Min_Salary"])
# creating empty data frame for storing filtering data
for i in range(25):
    limit = 0
    dummy_df = classy.loc[classy.Industry == lst_Industry[i]].reset_index(drop = True)
    # creating dummy df for top 10 industry
    for j in range(20):
        if limit == 5:
            break
        else:
            for k in range(dummy_df.Location.size):
                if lst_Location[j] == dummy_df.loc[k, "Location"]:
                    # append top 5 country and it's average salary of top 10 industry
                    top_10_avg_sal_industry_location = top_10_avg_sal_industry_location.append(dummy_df.loc[k])
                    limit += 1
                    break

# %%
classy = top_10_avg_sal_industry_location.melt(id_vars = ["Industry", "Location"], var_name = "Salaries")
px.sunburst(data_frame = classy, path = ["Industry", "Location", "Salaries"],values = "value", title = "Average salary of top 10 Industry in top 5 Location", height = 600)
# Out:
# <div>                            <div id="b62c96a8-23ab-458c-beab-c47111c7aad3" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b62c96a8-23ab-458c-beab-c47111c7aad3")) {                    Plotly.newPlot(                        "b62c96a8-23ab-458c-beab-c47111c7aad3",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["BPO/Bengaluru/Max_Salary","BPO/Delhi/Max_Salary","BPO/Hyderabad/Max_Salary","BPO/Mumbai/Max_Salary","BPO/Pune/Max_Salary","BPO/Bengaluru/Min_Salary","BPO/Delhi/Min_Salary","BPO/Hyderabad/Min_Salary","BPO/Mumbai/Min_Salary","BPO/Pune/Min_Salary","BPO/Bengaluru","BPO/Delhi","BPO/Hyderabad","BPO/Mum
# ...
